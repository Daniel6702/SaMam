# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')

# Load CSV file
# Replace 'data.csv' with your actual file path
df = pd.read_csv('.loss_logs/loss_20260504_103644.txt')

# Inspect columns (optional, good for debugging)
print(df.head())

# Plot selected columns against 'step'
plt.figure()

plt.plot(df['step'], df['val_loss'], label='val_loss')
plt.plot(df['step'], df['content'], label='content')
plt.plot(df['step'], df['style'], label='style')
plt.plot(df['step'], df['ssim'], label='ssim')

# Labels and legend
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Training Metrics Over Steps')
plt.legend()

# Show plot
plt.show()
# Out:
#    step    val_loss    content       style        id1        id2  ssim
# 0     0  310.072662  14.885921  191.174408  46.270035  57.742311   0.0
# 1   250  171.512646  19.265596   98.849964   3.294918  50.102168   0.0
# 2   500  149.195982  18.314817   81.532135   2.951383  46.397648   0.0
# 3   750  159.895184  17.958900   92.462484   3.537439  45.936359   0.0
# 4  1000  119.109686  17.157619   56.853819   2.799227  42.299022   0.0
