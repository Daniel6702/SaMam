# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV file
# Replace 'data.csv' with your actual file path
df = pd.read_csv('loss.txt')

# Inspect columns (optional, good for debugging)
print(df.head())

# Plot selected columns against 'step'
plt.figure()

plt.plot(df['step'], df['val_loss'], label='val_loss')
plt.plot(df['step'], df['content'], label='content')
plt.plot(df['step'], df['style'], label='style')
plt.plot(df['step'], df['ssim'], label='ssim')

# Labels and legend
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Training Metrics Over Steps')
plt.legend()

# Show plot
plt.show()
# Out:
#    step    val_loss    content       style  id1  id2  ssim
# 0     0  211.439102  15.006291  196.432816  0.0  0.0   0.0
# 1  1000   69.249901  22.086504   47.163398  0.0  0.0   0.0
# 2  2000   64.517289  20.506487   44.010802  0.0  0.0   0.0
# 3  3000   58.029981  19.422796   38.607185  0.0  0.0   0.0
# 4  4000   56.418418  19.100664   37.317754  0.0  0.0   0.0
